# %% [markdown]
# ### Config

# %%
# Configuration (keep all constants here for easy control)
RANDOM_STATE = 42
DATA_URL = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
TARGET_COL = "label"
TEXT_COL = "text"

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv(DATA_URL, sep="\t", header=None, names=[TARGET_COL, TEXT_COL])
print("Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
# Out:
# Shape: (5572, 2)
#
# Data Types:
#  label    object
# text     object
# dtype: object

# %%
# Preview
df.head(5)
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Check Missing Values

# %%
# Check for nulls
df.isna().sum()
# Out:
# label    0
# text     0
# dtype: int64

# %% [markdown]
# **Observation: Missing Values**
# - No missing values found in text or label columns
# - No immediate handling required

# %% [markdown]
# ### Check Duplicates

# %%
# Check duplicate rows
df.duplicated().sum()
# Out:
# 403

# %% [markdown]
# **Observation: Duplicate Rows**
# - Duplicate rows are present in the dataset
# - These can bias the model by over-representing certain samples
# - Will handle in preprocessing stage

# %% [markdown]
# ### Target Distribution

# %%
df[TARGET_COL].value_counts(normalize=True)
# Out:
# label
# ham     0.865937
# spam    0.134063
# Name: proportion, dtype: float64

# %% [markdown]
# **Observation: Class Distribution**
# - Dataset is imbalanced (spam is a minority class)
# - Accuracy alone may be misleading
# - Will consider metrics like F1-score and possible class weighting

# %% [markdown]
# ### Basic Text Inspection

# %% [markdown]
# #### 1. Random samples

# %%
df.sample(5, random_state=RANDOM_STATE)
# Out:
#      label                                               text
# 3245   ham  Squeeeeeze!! This is christmas hug.. If u lik ...
# 944    ham  And also I've sorta blown him off a couple tim...
# 1044   ham  Mmm thats better now i got a roast down me! i...
# 2484   ham      Mm have some kanji dont eat anything heavy ok
# 812    ham  So there's a ring that comes with the guys cos...

# %% [markdown]
# #### 2. Text Length Analysis

# %%
# Length of each message
df["text_length"] = df[TEXT_COL].apply(len)
df["text_length"].describe()
# Out:
# count    5572.000000
# mean       80.489950
# std        59.942907
# min         2.000000
# 25%        36.000000
# 50%        62.000000
# 75%       122.000000
# max       910.000000
# Name: text_length, dtype: float64

# %%
df.groupby(TARGET_COL)["text_length"].describe()
# Out:
#         count        mean        std   min    25%    50%    75%    max
# label
# ham    4825.0   71.482487  58.440652   2.0   33.0   52.0   93.0  910.0
# spam    747.0  138.670683  28.873603  13.0  133.0  149.0  157.0  223.0

# %% [markdown]
# **Observation: Text Length**
# - `spam` messages tend to be longer compared to `ham` messages
# - Text length could be a useful feature or signal

# %% [markdown]
# #### 3. Inspect Short vs Long Text

# %%
# Very short texts
df.sort_values("text_length").head(5)
# Out:
#      label text  text_length
# 4498   ham   Ok            2
# 3051   ham   Ok            2
# 1925   ham   Ok            2
# 5357   ham   Ok            2
# 3833   ham  Ok.            3

# %%
# Very long texts
df.sort_values("text_length", ascending=False).head(5)
# Out:
#      label                                               text  text_length
# 1085   ham  For me the love should start with attraction.i...          910
# 1863   ham  The last thing i ever wanted to do was hurt yo...          790
# 2434   ham  Indians r poor but India is not a poor country...          629
# 1579   ham  How to Make a girl Happy? It's not at all diff...          611
# 2158   ham  Sad story of a Man - Last week was my b'day. M...          588

# %% [markdown]
# #### 4. Empty / Suspicious Text

# %%
df[df["text_length"] <= 2]
# Out:
#      label text  text_length
# 1925   ham   Ok            2
# 3051   ham   Ok            2
# 4498   ham   Ok            2
# 5357   ham   Ok            2

# %% [markdown]
# **Observation: Raw Text Characteristics**
# - Text contains URLs, special characters, and inconsistent spacing
# - Spam messages often contain promotional patterns (numbers, offers, links)
# - Cleaning will be required before vectorization
